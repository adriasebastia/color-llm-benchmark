# %% [markdown]
# # Color LLM Benchmark - Python
#
# Notebook base para explorar imagenes, respuestas de modelos y metricas del benchmark.

# %% [markdown]
# ## Setup
#
# Ejecuta esta celda primero para comprobar que el entorno local esta activo.

# %%
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from PIL import Image

ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
DATA_DIR = ROOT / 'data'
RESULTS_DIR = ROOT / 'results'
RESULTS_DIR.mkdir(exist_ok=True)

print(f'Project root: {ROOT}')
print(f'pandas: {pd.__version__}')
# Out:
# Project root: C:\Users\AdriàSebastià\Documents\dev\color-llm-benchmark
# pandas: 3.0.2

# %% [markdown]
# ## Primer experimento
#
# Carga aqui una imagen de ejemplo y define la respuesta esperada antes de consultar modelos.

# %%
# example_image = DATA_DIR / 'raw' / 'example.png'
# image = Image.open(example_image).convert('RGB')
# image

# %%
# !python --version
# Out:
# Python 3.12.2
