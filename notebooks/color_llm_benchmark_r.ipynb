# %% [markdown]
# # Color LLM Benchmark - R
#
# Notebook base para analizar resultados del benchmark desde R.

# %% [markdown]
# ## Setup
#
# Antes de usar este notebook, instala R y ejecuta `Rscript scripts/setup_r.R` desde la raiz del proyecto.

# %%
library(tidyverse)
library(magick)
library(jsonlite)
library(httr2)
library(dotenv)

ROOT <- normalizePath(file.path(getwd(), '..'), mustWork = FALSE)
if (basename(getwd()) != 'notebooks') ROOT <- getwd()
DATA_DIR <- file.path(ROOT, 'data')
RESULTS_DIR <- file.path(ROOT, 'results')
dir.create(RESULTS_DIR, showWarnings = FALSE)

cat('Project root:', ROOT, '\n')
# Out:
# ── Attaching core tidyverse packages ──────────────────────────────────────────────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.2.1     ✔ readr     2.2.0
# ✔ forcats   1.0.1     ✔ stringr   1.6.0
# ✔ ggplot2   4.0.3     ✔ tibble    3.3.1
# ✔ lubridate 1.9.5     ✔ tidyr     1.3.2
# ✔ purrr     1.2.2
# ── Conflicts ────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ℹ Use the conflicted package (<http://conflicted.r-lib.org/>) to force all conflicts to become errors
# Linking to ImageMagick 6.9.13.29
# Enabled features: cairo, freetype, fftw, ghostscript, heic, lcms, pango, raw, rsvg, webp
# Disabled features: fontconfig, x11
#
#
# Adjuntando el paquete: 'jsonlite'
#
#
# The following object is masked from 'package:purrr':
#
#     flatten
# Project root: C:\Users\AdriàSebastià\Documents\dev\color-llm-benchmark

# %% [markdown]
# ## Primer analisis
#
# Carga aqui resultados exportados por el benchmark y resume metricas por modelo/color.

# %%
# results_path <- file.path(RESULTS_DIR, 'predictions.csv')
# predictions <- read_csv(results_path)
# predictions |> count(model, expected_color, predicted_color)

# %%
sessionInfo()
# Out:
# R version 4.5.3 (2026-03-11 ucrt)
# Platform: x86_64-w64-mingw32/x64
# Running under: Windows 11 x64 (build 26200)
#
# Matrix products: default
#   LAPACK version 3.12.1
#
# locale:
# [1] LC_COLLATE=Spanish_Spain.utf8  LC_CTYPE=Spanish_Spain.utf8
# [3] LC_MONETARY=Spanish_Spain.utf8 LC_NUMERIC=C
# [5] LC_TIME=Spanish_Spain.utf8
#
# time zone: Europe/Madrid
# tzcode source: internal
#
# attached base packages:
# [1] stats     graphics  grDevices utils     datasets  methods   base
#
# other attached packages:
#  [1] dotenv_1.0.3    httr2_1.2.2     jsonlite_2.0.0  magick_2.9.1
#  [5] lubridate_1.9.5 forcats_1.0.1   stringr_1.6.0   dplyr_1.2.1
#  [9] purrr_1.2.2     readr_2.2.0     tidyr_1.3.2     tibble_3.3.1
# [13] ggplot2_4.0.3   tidyverse_2.0.0
#
# loaded via a namespace (and not attached):
#  [1] gtable_0.3.6       compiler_4.5.3     crayon_1.5.3       Rcpp_1.1.1
#  [5] tidyselect_1.2.1   IRdisplay_1.1      systemfonts_1.3.2  scales_1.4.0
# ...

# %%
library(tidyverse)
library(magick)

R.version.string
cat("R kernel OK\n")
# Out:
# [1] "R version 4.5.3 (2026-03-11 ucrt)"
# R kernel OK
